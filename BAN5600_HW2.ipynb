# %% [markdown]
# <a href="https://colab.research.google.com/github/GamaGorch/Coding/blob/main/BAN5600_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PART 1***
#
# **Problem 1:**

# %%
import random  # Import random module to gen random numbers
import math    # Import math module to use functions

# Generate two float numbers between 0 and 1
u = random.random()
v = random.random()

# Apply the formula to transform random numbers
# into a standard Gaussian random variable Z
# Formula: Z = sin(2 * pi * v) * sqrt(-2 * ln(u))
Z = math.sin(2 * math.pi * v) * math.sqrt(-2 * math.log(u))

# Display the values of u, v, and the resulting Gaussian random variable Z
print(f"u = {u}")
print(f"v = {v}")
print(f"Z = {Z}")
# Out:
# u = 0.4442893180162647
# v = 0.08087109332869713
# Z = 0.6197565625535751

# %% [markdown]
# **Problem 2:**

# %%
# Use the input() to prompt user
# Ask the user to enter two integer values
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))

# Compare the two values and print them in ascending order
if a <= b:
    # if a is already less than or equal to b, print as is
    print(a, b)
else:
    # if b is smaller, so print b first, then a
    print(b, a)
# Out:
# Enter first integer: 1
# Enter second integer: 2
# 1 2

# %% [markdown]
# **Problem 3:**

# %%
# Use input() to prompt the user directly

# Ask the user to enter three float values
x = float(input("Enter first value: "))
y = float(input("Enter second value: "))
z = float(input("Enter third value: "))

# Check if values are strictly ascending (x < y < z)
# or check if strictly descending (x > y > z)
if (x < y < z) or (x > y > z):
    print("True")   # Values are in strict order
else:
    print("False")  # Values are not in strict ascending or descending order
# Out:
# Enter first value: 1
# Enter second value: 2
# Enter third value: 3
# True

# %% [markdown]
# **Problem 4:**

# %%
# Prompt the user to enter an earthquake magnitude as a decimal number
magnitude = float(input("Enter earthquake magnitude: "))

# Use if-elif-else to match the magnitude to its descriptor
# Each condition checks the upper boundary of each range
if magnitude < 2.0:
    descriptor = "Micro"
elif magnitude < 3.0:
    descriptor = "Very Minor"
elif magnitude < 4.0:
    descriptor = "Minor"
elif magnitude < 5.0:
    descriptor = "Light"
elif magnitude < 6.0:
    descriptor = "Moderate"
elif magnitude < 7.0:
    descriptor = "Strong"
elif magnitude < 8.0:
    descriptor = "Major"
elif magnitude < 10.0:
    descriptor = "Great"
else:
    descriptor = "Meteoric"

# Display s message with the magnitude and its descriptor
print(f"A magnitude {magnitude} earthquake is considered to be a {descriptor} earthquake.")
# Out:
# Enter earthquake magnitude: 5
# A magnitude 5.0 earthquake is considered to be a Moderate earthquake.

# %% [markdown]
# **Problem 5:**

# %%
# in order to print actually print the numbers, we would need something like print(list(range(1,22,3))) -> [1,4,7,10,13,16,19]
print(range(1, 22, 3))
# Out:
# range(1, 22, 3)

# %% [markdown]
# **Problem 6:**

# %%
s = 'I ate it.'         # Defines a string variable

print(s.upper())        # .upper() converts all characters to uppercase
                        # Output is: I ATE IT.

print(s.count('t'))     # .count('t') counts how many times a lowercase 't' appears
                        # 't' appears in 'ate' and 'it' so the count is 2
                        # Output: 2

w = s.split()           # .split() with no arguments splits on any whitespace
                        # breaks the string into a list of words
print(w)                # output: ['I', 'ate', 'it.']
# Out:
# I ATE IT.
# 2
# ['I', 'ate', 'it.']

# %% [markdown]
# ***Part 2***
#
# **Problem 1:**
#
# In my automation problem, my Python code is acting as the client because it is making requests to external services to retrieve or send data.
#
# For example, if my script is pulling data from Google Sheets or sending a message to Slack, it is initiating the request and waiting for a response. The server (Google, Slack, or any other playform) is responsible for processing that request and returning the correct data or confirmation.
#
# This means my script that i create behaves like a customer in the restaurant, it asks for specific information or actions and relies on the server to fulfill them.

# %% [markdown]
# **Problem 3:**
#
# If I were building an API for my business process, one key function I would allow users to request is get_weekly_sales_report
#
# This would allow a user to request a summary of sales data for a given week.
#
# For example, the user could provide a date range, and the API would return total sales, top-performing products, and key metrics.
#
# This is useful because it simplifies access to important business insights without requiring the user to manually gather the data themselves.

# %% [markdown]
# **Problem 3:**
#
# If the DNS system were hacked and redirected my bank’s website to a fake server, my browser could detect the difference using HTTPS and SSL/TLS certificates.
#
# When visiting a secure website, the server provides a digital certificate issued by a trusted certificate Authority. My browser checks this certificate to verify that the website is legitimate and matches the domain name.
#
# If the certificate is missing, invalid, or does not match the domain, the browser will display a warning. This helps protect users from phishing or fake websites, even if the DNS has been compromised.
